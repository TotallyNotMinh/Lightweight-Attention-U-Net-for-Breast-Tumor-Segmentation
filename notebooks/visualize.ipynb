    0.1208, 0.1127, 0.1168, 0.1159, 0.1186, 0.1219, 0.1222, 0.1282, 0.1271, 0.1204,
    0.1236, 0.1263, 0.1218, 0.1294, 0.1211, 0.1191, 0.1194, 0.1211, 0.1284, 0.1312,
    0.1251, 0.1243, 0.1243, 0.1217, 0.1244, 0.1218, 0.1240, 0.1185, 0.1239, 0.1284,
    0.1241, 0.1205, 0.1220, 0.1261, 0.1265, 0.1289, 0.1438, 0.1376, 0.1290, 0.1341,
    0.1287, 0.1284, 0.1323, 0.1215, 0.1306, 0.1265, 0.1256, 0.1280, 0.1247, 0.1279,
    0.1320, 0.1330, 0.1302, 0.1331, 0.1289, 0.1321, 0.1322, 0.1225, 0.1315, 0.1337,
    0.1208, 0.1261, 0.1297, 0.1252
]

dice_score = [
    0.1157, 0.1575, 0.2347, 0.2585, 0.3144, 0.3413, 0.4335, 0.4941, 0.5646, 0.5801,
    0.6624, 0.6178, 0.6594, 0.6849, 0.6466, 0.6998, 0.7280, 0.7202, 0.6911, 0.7405,
    0.7359, 0.7409, 0.7349, 0.7193, 0.7091, 0.6873, 0.7270, 0.7326, 0.7245, 0.7361,
    0.7416, 0.7390, 0.7424, 0.7167, 0.7676, 0.7251, 0.7504, 0.7541, 0.7560, 0.7612,
    0.7627, 0.7375, 0.7570, 0.7721, 0.7510, 0.7636, 0.7849, 0.7694, 0.7715, 0.7681,
    0.7667, 0.7368, 0.7530, 0.7276, 0.7444, 0.7607, 0.7463, 0.7560, 0.7560, 0.7615,
    0.7514, 0.7585, 0.7639, 0.7602, 0.7456, 0.7601, 0.7668, 0.7735, 0.7695, 0.7706,
    0.7663, 0.7608, 0.7550, 0.7726, 0.7670, 0.7645, 0.7656, 0.7786, 0.7680, 0.7754,
    0.7622, 0.7879, 0.7812, 0.7869, 0.8012, 0.7767, 0.7681, 0.7675, 0.7687, 0.7716,
    0.7661, 0.7646, 0.7738, 0.7613, 0.7741, 0.7702, 0.7761, 0.7766, 0.7666, 0.7652,
    0.7643, 0.7690, 0.7768, 0.7824, 0.7814, 0.7776, 0.7789, 0.7813, 0.7777, 0.7716,
    0.7711, 0.7775, 0.7834, 0.7716, 0.7695, 0.7749, 0.7592, 0.7707, 0.7735, 0.7697,
    0.7784, 0.7689, 0.7735, 0.7774, 0.7691, 0.7630, 0.7748, 0.7676, 0.7721, 0.7758,
    0.7629, 0.7670, 0.7666, 0.7582, 0.7658, 0.7707, 0.7636, 0.7861, 0.7739, 0.7664,
    0.7918, 0.7779, 0.7703, 0.7724
]

# %%
plt.figure(figsize=(20, 10))

plt.plot(epochs, train_loss, label="Train Loss")
plt.plot(epochs, val_loss, label="Validation Loss")
plt.plot(epochs, dice_score, label="Dice Loss")

plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.title("Training and Validation Loss Curves")

plt.legend()
plt.grid(True)

plt.show()

# %%
print(min(train_loss))
# Out:
# 0.0666

# %%
print(min(val_loss))
# Out:
# 0.1127

# %%
print(max(dice_score))
# Out:
# 0.8012
